# %%
import numpy as np
import and_logic_generator as and_gen
import and_gate_pipeline as pipeline
import matplotlib.pyplot as plt

# reload modules every 2 seconds
# %load_ext autoreload
# %autoreload 2

# %%
# Repeatable seed
random_state = 2**12
np.random.seed(seed=random_state)

# %%
# Prepare samples
n = 2000
x, y = and_gen.generate_logistic_samples(n)
x = x - 0.5
shift = [[-0.5, -0.5]]

# %%
and_gate_pipeline = pipeline.LogicGatePipeline(x, y)
and_gate_pipeline.random_state = random_state

# %%
# Parameters for figures
figsize = np.array(plt.rcParams["figure.figsize"]) * 2
x_max = np.amax(x, axis=0) * 1.1
x_min = np.amin(x, axis=0) * 1.1

and_gate_pipeline.plot_data(
    figsize=figsize, xlim=[x_min[0], x_max[0]], ylim=[x_min[1], x_max[1]])

# %%
# 80:20 split on training and test sets
and_gate_pipeline.train_test_split(0.2)
# Out:
# Train test split: 0.80:0.20

# %%
# Parameters for SVM
gamma='scale'
C=1000

and_gate_pipeline.fit_svm_model(gamma=gamma, C=C, shift=shift)
# Out:
# With gamma = scale and C = 1000
# Accuracy on train set = 99.3750%
# Accuracy on test set  = 99.2500%
# Passed basic test

# %%
and_gate_pipeline.plot_prediction(
    figsize, h=0.01, 
    mesh_xlim=[x_min[0], x_max[0]], mesh_ylim=[x_min[1], x_max[1]], 
    xlim=[x_min[0], x_max[0]], ylim=[x_min[1], x_max[1]])

# %%
and_gate_pipeline.model.get_params()
# Out:
# {'C': 1000,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': 4096,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
# Parameter for stepping size of Adversarial Examples
epsilon=0.0006

and_gate_pipeline.generate_adversarial_examples(epsilon=epsilon)
# Out:
# Negative mean = [-0.0589, -0.0708]
# Positive mean = [0.2069, 0.2143]
# Completed after 2129 epoch...
# Misclassified = 199
# Misclassified negative = 39 (9.7500%)
# Misclassified positive = 160 (40.0000%)
# Found 199 Adversarial Examples out of 400. 49.7500% successful rate

# %%
and_gate_pipeline.plot_adversarial_examples(
    figsize, h=0.001,
    mesh_xlim=[-0.1, 1.2], mesh_ylim=[-0.1, 1.2],
    xlim=[-0.1, 1.2], ylim=[-0.1, 1.2])

# %%
# Parameters for Applicability Domain
k = 9
zeta0 = -0.1
zeta1 = -0.2

and_gate_pipeline.run_applicability_domain(zeta0=zeta0, zeta1=zeta1, k=k)
# Out:
# ---------- Applicability ---------------
# Pass rate = 100.0000%
#
# ---------- Reliability -----------------
#
# In 0 class:
# Threshold = 0.0371
# Average mean = 0.0315
# Passed indices:
# 1, 3, 6, 8, 12, 19, 24, 25, 30, 41, 42, 46, 51, 68, 70, 71, 75, 76, 92, 95, 99, 103, 109, 114, 121, 123, 132, 141, 142, 149, 150, 153, 154, 156, 157, 160, 163, 166, 167, 168, 176, 180, 182, 184, 186, 190, 202, 205, 217, 218, 225, 230, 231, 234, 241, 257, 269, 275, 278, 281, 291, 297, 299, 301, 303, 306, 309, 327, 329, 332, 338, 345, 351, 352, 355, 357, 375, 379, 384, 385, 393, 394
#
# In 1 class:
# Threshold = 0.0332
# Average mean = 0.0335
# Passed indices:
# 0, 5, 7, 9, 13, 14, 15, 21, 26, 28, 29, 32, 35, 36, 38, 43, 45, 47, 49, 52, 53, 56, 58, 59, 61, 62, 63, 64, 65, 67, 74, 77, 78, 79, 81, 86, 89, 91, 96, 97, 100, 101, 102, 105, 106, 112, 116, 117, 118, 119, 120, 122, 124, 135, 139, 140, 144, 145, 147, 152, 158, 159, 161, 164, 170, 171, 172, 174, 175, 181, 183, 185, 187, 193, 194, 200, 207, 208, 209, 210, 215, 216, 219, 224, 226, 227, 229, 232, 235, 237, 238, 239, 243, 245, 246, 247, 248, 249, 255, 256, 259, 262, 263, 266, 268, 271, 272, 273, 274, 279, 280, 283, 284, 287, 288, 290, 292, 294, 296, 298, 300, 302, 307, 308, 310, 312, 314, 315, 316, 324, 326, 331, 333, 334, 335, 342, 344, 346, 348, 354, 356, 358, 359, 360, 362, 368, 369, 370, 371, 374, 377, 378, 380, 382, 383, 387, 388, 389, 390, 391, 392, 397
# Distance of c0 in training set:
# Mean               = 0.0422
# Standard deviation = 0.0517
# Threshold          = 0.0371
#
# Distance of c1 in training set:
# Mean               = 0.0422
# Standard deviation = 0.0447
# Threshold          = 0.0332
#
# Pass rate = 61.0000%
#
# ---------- Decidability ----------------
# Pass rate = 36.0656%
#
# ---------- Results ---------------------
# Accuracy before AD = 50.2500%
#
# Overall pass rate = 22.0000%
# Accuracy after AD = 81.8182%
# 88 out of 400
#
# Misclassified = 16
# Misclassified negative = 4 (4.5455%)
# Misclassified positive = 12 (13.6364%)
# [ 0.4019, -0.0006] = 1; True y = 0
# [ 0.1323, -0.0003] = 1; True y = 0
# [-0.0025,  0.3584] = 1; True y = 0
# [ 0.1798,  0.0010] = 0; True y = 1
# [ 0.1638,  0.0015] = 0; True y = 1
# [-0.0026,  0.3029] = 1; True y = 0
# [ 0.2064,  0.0025] = 0; True y = 1
# [ 0.0015,  0.0326] = 1; True y = 0
# [ 0.1200, -0.0004] = 0; True y = 1
# [-0.0021,  0.2146] = 1; True y = 0
# [ 0.2073,  0.0023] = 1; True y = 0
# [-0.0022,  0.2142] = 1; True y = 0
# [-0.0025,  0.2140] = 1; True y = 0
# [-0.0024,  0.2533] = 1; True y = 0
# [ 0.2066,  0.0022] = 1; True y = 0
# [-0.0023,  0.2145] = 1; True y = 0

# %%
and_gate_pipeline.plot_after_ad(
    figsize, h=0.001,
    mesh_xlim=[-0.1, 1.2], mesh_ylim=[-0.1, 1.2],
    xlim=[-0.1, 1.2],ylim=[-0.1, 1.2])
